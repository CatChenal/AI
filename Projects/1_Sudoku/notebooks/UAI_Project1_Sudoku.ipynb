# %% [markdown]
# # Udacity AI - Project 1: Sudoku

# %%
# %load nb_cell0.py
import os
import sys
from pathlib import Path

print('Python: {}; sys.prefix: {}\n'.format(sys.version, sys.prefix))
print('Currrent dir:', Path.cwd())

# TODO: convert os. code to work with Path
def add_to_sys_path(this_path, up=False):
    """
    Prepend this_path to sys.path.
    If up=True, path refers to parent folder (1 level up).
    """
    for p in sys.path:
        p = os.path.abspath(p)
    if up:
        newp = os.path.abspath(os.path.join(this_path, '..'))
    else:
        newp = os.path.abspath(this_path)
        
    if this_path not in (p, p + os.sep):
        print('Path added to sys.path: {}'.format(newp))
        sys.path.insert(0, newp)
        
# if notebook inside another folder, eg ./notebooks:
up =  os.path.abspath(os.path.curdir).endswith('notebooks')
add_to_sys_path(os.path.curdir, up)

if up:
    DIR_IMG = Path.cwd().parent.joinpath('Images')
else:
    DIR_IMG = Path.cwd().joinpath('Images')
if not DIR_IMG.exists():
    Path.mkdir(DIR_IMG)
    
import numpy as np
from pprint import pprint as pp

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
from IPython.display import HTML, Markdown, IFrame, Image

#display(HTML("<style>.container { width:100% !important; }</style>"))

def new_section(title):
    style = "text-align:center;background:#c2d3ef;padding:20px;color:#ffffff;font-size:3em;width:98%"
    return HTML('<div style="{}">{}</div>'.format(style, title))

def filter_dir(obj, start_with_str='_', exclude=True):
    return [d for d in dir(obj) if not d.startswith(start_with_str) == exclude]

import inspect

def get_mdl_pkgs(alib):
    "Inspect module hierarchy on two levels ony."
    pkgs = {}
    for name, mdl in inspect.getmembers(alib, inspect.ismodule):
        print('\n{:>13} : {}'.format(mdl.__name__, filter_dir(mdl)))
        for mdl_name, mdl_sub in inspect.getmembers(mdl, inspect.ismodule):
            if mdl_sub.__doc__:
                print('\n{:>20} : {}'.format(mdl_name, mdl_sub.__doc__.strip()))

# %load_ext autoreload
# %autoreload 2
# Out:
# Python: 3.6.7 (default, Feb 28 2019, 07:28:18) [MSC v.1900 64 bit (AMD64)]; sys.prefix: C:\Users\catch\Anaconda3\envs\dsml
#
# Currrent dir: C:\Users\catch\Documents\GH_Projects\U_AI\project1\notebooks
# Path added to sys.path: C:\Users\catch\Documents\GH_Projects\U_AI\project1

# %%
test_grid0 = '..3.2.6..9003.5..1..18.64....81.29..7......8..67.82....26.95..8..2.3..9..5.1.3.0'
test_grid1 = '..3.2.6..9003.5..1..18.64....81.29..7.......8..67.82....26.95..8..2.3..9..5.1.3.0'
test_grid2 = '4.....8.5.3.....0....7......2.....6...c.8.4......1.......6.3.7.5..2.....1.4......'

diagonal_grid = '2.............62....1....7...6..8...3...9...7...6..4...4....8....52.............3'
solved_diag_sudoku = {'G7': '8', 'G6': '9', 'G5': '7', 'G4': '3', 'G3': '2', 'G2': '4', 'G1': '6', 'G9': '5',
                          'G8': '1', 'C9': '6', 'C8': '7', 'C3': '1', 'C2': '9', 'C1': '4', 'C7': '5', 'C6': '3',
                          'C5': '2', 'C4': '8', 'E5': '9', 'E4': '1', 'F1': '1', 'F2': '2', 'F3': '9', 'F4': '6',
                          'F5': '5', 'F6': '7', 'F7': '4', 'F8': '3', 'F9': '8', 'B4': '7', 'B5': '1', 'B6': '6',
                          'B7': '2', 'B1': '8', 'B2': '5', 'B3': '3', 'B8': '4', 'B9': '9', 'I9': '3', 'I8': '2',
                          'I1': '7', 'I3': '8', 'I2': '1', 'I5': '6', 'I4': '5', 'I7': '9', 'I6': '4', 'A1': '2',
                          'A3': '7', 'A2': '6', 'E9': '7', 'A4': '9', 'A7': '3', 'A6': '5', 'A9': '1', 'A8': '8',
                          'E7': '6', 'E6': '2', 'E1': '3', 'E3': '4', 'E2': '8', 'E8': '5', 'A5': '4', 'H8': '6',
                          'H9': '4', 'H2': '3', 'H3': '5', 'H1': '9', 'H6': '1', 'H7': '7', 'H4': '2', 'H5': '8',
                          'D8': '9', 'D9': '2', 'D6': '8', 'D7': '1', 'D4': '4', 'D5': '3', 'D2': '7', 'D3': '6',
                          'D1': '5'}

before_naked_twins_1 = {'I6': '4', 'H9': '3', 'I2': '6', 'E8': '1', 'H3': '5', 'H7': '8', 'I7': '1', 'I4': '8',
                            'H5': '6', 'F9': '7', 'G7': '6', 'G6': '3', 'G5': '2', 'E1': '8', 'G3': '1', 'G2': '8',
                            'G1': '7', 'I1': '23', 'C8': '5', 'I3': '23', 'E5': '347', 'I5': '5', 'C9': '1', 'G9': '5',
                            'G8': '4', 'A1': '1', 'A3': '4', 'A2': '237', 'A5': '9', 'A4': '2357', 'A7': '27',
                            'A6': '257', 'C3': '8', 'C2': '237', 'C1': '23', 'E6': '579', 'C7': '9', 'C6': '6',
                            'C5': '37', 'C4': '4', 'I9': '9', 'D8': '8', 'I8': '7', 'E4': '6', 'D9': '6', 'H8': '2',
                            'F6': '125', 'A9': '8', 'G4': '9', 'A8': '6', 'E7': '345', 'E3': '379', 'F1': '6',
                            'F2': '4', 'F3': '23', 'F4': '1235', 'F5': '8', 'E2': '37', 'F7': '35', 'F8': '9',
                            'D2': '1', 'H1': '4', 'H6': '17', 'H2': '9', 'H4': '17', 'D3': '2379', 'B4': '27',
                            'B5': '1', 'B6': '8', 'B7': '27', 'E9': '2', 'B1': '9', 'B2': '5', 'B3': '6', 'D6': '279',
                            'D7': '34', 'D4': '237', 'D5': '347', 'B8': '3', 'B9': '4', 'D1': '5'}
possible_solutions_1 = [
        {'G7': '6', 'G6': '3', 'G5': '2', 'G4': '9', 'G3': '1', 'G2': '8', 'G1': '7', 'G9': '5', 'G8': '4', 'C9': '1',
         'C8': '5', 'C3': '8', 'C2': '237', 'C1': '23', 'C7': '9', 'C6': '6', 'C5': '37', 'A4': '2357', 'A9': '8',
         'A8': '6', 'F1': '6', 'F2': '4', 'F3': '23', 'F4': '1235', 'F5': '8', 'F6': '125', 'F7': '35', 'F8': '9',
         'F9': '7', 'B4': '27', 'B5': '1', 'B6': '8', 'B7': '27', 'E9': '2', 'B1': '9', 'B2': '5', 'B3': '6', 'C4': '4',
         'B8': '3', 'B9': '4', 'I9': '9', 'I8': '7', 'I1': '23', 'I3': '23', 'I2': '6', 'I5': '5', 'I4': '8', 'I7': '1',
         'I6': '4', 'A1': '1', 'A3': '4', 'A2': '237', 'A5': '9', 'E8': '1', 'A7': '27', 'A6': '257', 'E5': '347',
         'E4': '6', 'E7': '345', 'E6': '579', 'E1': '8', 'E3': '79', 'E2': '37', 'H8': '2', 'H9': '3', 'H2': '9',
print('Failed test:')
sol.display(tested)

print('\nMy output:')
sol.display(my_out)
# Out:
# Failed test:
#  2345689   234568     7    |  34568      1      23689  |  234568   345689    2458
#  2345689  1234568  1234569 |  345678  23456789  236789 | 2345678  3456789   124578
#  2345689  1234568  1234569 |  345678  23456789  236789 | 2345678  3456789   124578
# ---------------------------+---------------------------+---------------------------
#     36       9        8    |    1        36       5    |    47       2        47
#    567      567       56   |    2       678       4    |    9        1        3
#     1        24       24   |    9        37       37   |    58       58       6
# ---------------------------+---------------------------+---------------------------
#  23456789 12345678 1234569 |  345678  23456789 1236789 | 2345678   345678   24578
#  23456789 12345678 1234569 |  345678  23456789 1236789 | 2345678   345678   24578
#  2345678  2345678   23456  |  345678  2345678   23678  |    1      345678     9
#
# My output:
# ...

# %%
values = sol.eliminate(tested)
sol.display(values)
# Out:
#   234568   234568     7    |  34568      1      23689  |  234568   345689    248
#  2345689   234568  1234569 |  345678  23456789  236789 | 2345678   34678    124578
#  2345689  1234568   23456  |  345678  23456789  236789 |  234678  3456789   124578
# ---------------------------+---------------------------+---------------------------
#     36       9        8    |    1        36       5    |    47       2        47
#    567      567       56   |    2       678       4    |    9        1        3
#     1        24       24   |    9        37       37   |    58       58       6
# ---------------------------+---------------------------+---------------------------
#  23456789 12345678  12346  |  345678  23456789 1236789 | 2345678   345678   24578
#  23456789 1234678  1234569 |  345678  23456789 1236789 | 2345678   345678   24578
#   234678  2345678   23456  |  345678  2345678   23678  |    1      345678     9

# %%
assert(sorted(values) == sorted(my_out))

# %%
values = sol.naked_twins(values)
sol.display(values)
# Out:
#   234568   234568     7    |  34568      1      23689  |  234568   345689    248
#  2345689   234568  1234569 |  345678  23456789  236789 | 2345678   34678    124578
#  2345689  1234568   23456  |  345678  23456789  236789 |  234678  3456789   124578
# ---------------------------+---------------------------+---------------------------
#     36       9        8    |    1        6        5    |    47       2        47
#    567      567       56   |    2        68       4    |    9        1        3
#     1        24       24   |    9        37       37   |    58       58       6
# ---------------------------+---------------------------+---------------------------
#  23456789 12345678  12346  |  345678  23456789 1236789 | 2345678   345678   24578
#  23456789 1234678  1234569 |  345678  23456789 1236789 | 2345678   345678   24578
#   234678  2345678   23456  |  345678  2345678   23678  |    1      345678     9

# %%
values = sol.only_choice(values)
sol.display(values)
# Out:
#   234568   234568     7    |  34568      1      23689  |  234568   345689    248
#  2345689   234568  1234569 |  345678  23456789  236789 | 2345678   34678    124578
#  2345689  1234568   23456  |  345678  23456789  236789 |  234678  3456789   124578
# ---------------------------+---------------------------+---------------------------
#     3        9        8    |    1        6        5    |    47       2        47
#    567      567       56   |    2        8        4    |    9        1        3
#     1        24       24   |    9        37       37   |    58       58       6
# ---------------------------+---------------------------+---------------------------
#  23456789 12345678  12346  |  345678  23456789 1236789 | 2345678   345678   24578
#  23456789 1234678  1234569 |  345678  23456789 1236789 | 2345678   345678   24578
#   234678  2345678   23456  |  345678  2345678   23678  |    1      345678     9

# %%
from collections import defaultdict

peers_len_d = defaultdict(list)
for k, v in peers.items():
    peers_len_d[len(v)].append(k)
    
for k in peers_len_d.keys():
    print(f'{k}:\t', peers_len_d[k])
# Out:
# 26:	 ['A1', 'A9', 'B2', 'B8', 'C3', 'C7', 'D4', 'D6', 'F4', 'F6', 'G3', 'G7', 'H2', 'H8', 'I1', 'I9']
# 20:	 ['A2', 'A3', 'A4', 'A5', 'A6', 'A7', 'A8', 'B1', 'B3', 'B4', 'B5', 'B6', 'B7', 'B9', 'C1', 'C2', 'C4', 'C5', 'C6', 'C8', 'C9', 'D1', 'D2', 'D3', 'D5', 'D7', 'D8', 'D9', 'E1', 'E2', 'E3', 'E4', 'E6', 'E7', 'E8', 'E9', 'F1', 'F2', 'F3', 'F5', 'F7', 'F8', 'F9', 'G1', 'G2', 'G4', 'G5', 'G6', 'G8', 'G9', 'H1', 'H3', 'H4', 'H5', 'H6', 'H7', 'H9', 'I2', 'I3', 'I4', 'I5', 'I6', 'I7', 'I8']
# 32:	 ['E5']

# %% [markdown]
# > The naked twins strategy says that if you have two or more unallocated boxes
# in a unit and there are only two digits that can go in those two boxes, then
# those two digits can be eliminated from the possible assignments of all other
# boxes in the same unit.

# %%
print('Testing naked\n')

values = tested
sol.display(values)
print()
# Out:
# Testing naked
#
#  2345689   234568     7    |  34568      1      23689  |  234568   345689    2458
#  2345689  1234568  1234569 |  345678  23456789  236789 | 2345678  3456789   124578
#  2345689  1234568  1234569 |  345678  23456789  236789 | 2345678  3456789   124578
# ---------------------------+---------------------------+---------------------------
#     36       9        8    |    1        6        5    |    47       2        47
#    567      567       56   |    2        68       4    |    9        1        3
#     1        24       24   |    9        37       37   |    58       58       6
# ---------------------------+---------------------------+---------------------------
#  23456789 12345678 1234569 |  345678  23456789 1236789 | 2345678   345678   24578
#  23456789 12345678 1234569 |  345678  23456789 1236789 | 2345678   345678   24578
#  2345678  2345678   23456  |  345678  2345678   23678  |    1      345678     9

# %%
values = sol.eliminate(values)
sol.display(values)
# Out:
#   234568   234568     7    |  34568      1      23689  |  234568   345689    248
#  2345689   234568  1234569 |  345678  2345789   236789 | 2345678   34678    124578
#  2345689  1234568   23456  |  345678  2345789   236789 |  234678  3456789   124578
# ---------------------------+---------------------------+---------------------------
#     3        9        8    |    1        6        5    |    47       2        47
#    567      567       56   |    2        8        4    |    9        1        3
#     1        24       24   |    9        37       37   |    58       58       6
# ---------------------------+---------------------------+---------------------------
#  23456789 12345678  12346  |  345678  2345789  1236789 | 2345678   345678   24578
#  23456789 1234678  1234569 |  345678  2345789  1236789 | 2345678   345678   24578
#   234678  2345678   23456  |  345678   234578   23678  |    1      345678     9

# %%
values = sol.naked_twins(values)
sol.display(values)
# Out:
#   234568   234568     7    |  34568      1      23689  |  234568   345689    248
#  2345689   234568  1234569 |  345678  2345789   236789 | 2345678   34678    124578
#  2345689  1234568   23456  |  345678  2345789   236789 |  234678  3456789   124578
# ---------------------------+---------------------------+---------------------------
#     3        9        8    |    1        6        5    |    47       2        47
#    567      567       56   |    2        8        4    |    9        1        3
#     1        24       24   |    9        37       37   |    58       58       6
# ---------------------------+---------------------------+---------------------------
#  23456789 12345678  12346  |  345678  2345789  1236789 | 2345678   345678   24578
#  23456789 1234678  1234569 |  345678  2345789  1236789 | 2345678   345678   24578
#   234678  2345678   23456  |  345678   234578   23678  |    1      345678     9

# %%
result = sol.search(tested)
sol.display(result)
# Out:
# 4 3 7 |5 1 9 |6 8 2
# 9 6 1 |3 2 8 |7 4 5
# 8 5 2 |6 4 7 |3 9 1
# ------+------+------
# 3 9 8 |1 6 5 |4 2 7
# 6 7 5 |2 8 4 |9 1 3
# 1 2 4 |9 7 3 |8 5 6
# ------+------+------
# 2 4 6 |7 9 1 |5 3 8
# 5 1 9 |8 3 6 |2 7 4
# 7 8 3 |4 5 2 |1 6 9

# %%
assert(values in possible_solutions_1)

# %%
solved2 = possible_solutions_1[1]
sol.display(solved2)
# Out:
#   1   237   4  | 2357  9   257 |  27   6    8
#   9    5    6  |  27   1    8  |  27   3    4
#   23  237   8  |  4    37   6  |  9    5    1
# ---------------+---------------+---------------
#   5    1    79 | 237  347  279 |  34   8    6
#   8    3    79 |  6   347  579 | 345   1    2
#   6    4    23 | 1235  8   125 |  35   9    7
# ---------------+---------------+---------------
#   7    8    1  |  9    2    3  |  6    4    5
#   4    9    5  |  17   6    17 |  8    2    3
#   23   6    23 |  8    5    4  |  1    7    9

# %% [raw]
# print('Initial board:\n\t{}\n'.format(diagonal_grid))
# values = sol.grid2values(diagonal_grid)
# sol.display(values)
# print()
#
# values = sol.eliminate(values)
# sol.display(values)

# %%
values = sol.only_choice(values)
sol.display(values)
# Out:
#    2     356789  34789  |1345789  134578  134579 | 13569  1345689   145
#  45789     57    34789  |1345789  134578    6    |   2      1345   14589
#  45689   35689     1    | 34589   23458   23459  |   35      7     45689
# ------------------------+------------------------+------------------------
#  14579   12579     6    |  457    123457    8    |  1359   12359    1259
#    3      1258    248   |  145      9      1245  |  156    12568     7
#  15789   125789   2789  |   6     12357     57   |   4     123589  12589
# ------------------------+------------------------+------------------------
#   1679     4       2    | 13579   13567   13579  |   8     12569   12569
#  16789    137      5    |   2     134678  13479  |  1679     6      1469
#    17    126789   2789  | 145789  145678  14579  | 15679   124569    3

# %%
values = sol.naked_twins(values)
sol.display(values)
# Out:
# Pool (diff): {'E2', 'B3', 'G2', 'H2', 'B1', 'G7', 'A2', 'B8', 'H8', 'B5', 'C1', 'C2', 'B9', 'B4', 'A1', 'E5', 'D2', 'I9', 'I2', 'D4', 'C3', 'F2', 'A3', 'B6', 'B7'}
# Pool (diff): {'G7', 'F1', 'F9', 'H8', 'C6', 'H6', 'G6', 'I6', 'D5', 'A6', 'E5', 'A1', 'F5', 'I9', 'D6', 'F7', 'D4', 'F4', 'F8', 'E4', 'C3', 'E6', 'F2', 'F3', 'B6'}
#    2      3689    3489  |1345789  134578   1349  | 13569  1345689   145
#   489      57     3489  | 13489    1348     6    |   2      134     1489
#   4689    3689     1    | 34589   23458    2349  |   35      7     45689
# ------------------------+------------------------+------------------------
#  14579    129      6    |   4      1234     8    |  1359   12359    1259
#    3      128     248   |   14      9      124   |  156    12568     7
#   189     1289    289   |   6      123      57   |   4     12389    1289
# ------------------------+------------------------+------------------------
# ...

# %%
s1 = sorted({'E2', 'B3', 'G2', 'H2', 'B1', 'G7', 'A2', 'B8', 'H8', 'B5', 'C1', 'C2', 'B9', 'B4', 'A1', 'E5', 'D2', 'I9', 'I2', 'D4', 'C3', 'F2', 'A3', 'B6', 'B7'})
s2 = sorted({'G7', 'F1', 'F9', 'H8', 'C6', 'H6', 'G6', 'I6', 'D5', 'A6', 'E5', 'A1', 'F5', 'I9', 'D6', 'F7', 'D4', 'F4', 'F8', 'E4', 'C3', 'E6', 'F2', 'F3', 'B6'})
s1 == s2
# Out:
# False

# %%
print(s1)
print(s2)
# Out:
# ['A1', 'A2', 'A3', 'B1', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B9', 'C1', 'C2', 'C3', 'D2', 'D4', 'E2', 'E5', 'F2', 'G2', 'G7', 'H2', 'H8', 'I2', 'I9']
# ['A1', 'A6', 'B6', 'C3', 'C6', 'D4', 'D5', 'D6', 'E4', 'E5', 'E6', 'F1', 'F2', 'F3', 'F4', 'F5', 'F7', 'F8', 'F9', 'G6', 'G7', 'H6', 'H8', 'I6', 'I9']

# %%
values = naked(values)
sol.display(values)
# Out:
# Twins: B2: 57 & F6: 57
# Pool (diff): {'B4', 'B8', 'E2', 'E5', 'B5', 'B1', 'A1', 'H8', 'C2', 'A2', 'H2', 'B3', 'C3', 'G7', 'B7', 'F2', 'B9', 'B6', 'G2', 'I2', 'D2', 'I9', 'A3', 'C1', 'D4'}
# Twins: F6: 57 & B2: 57
# Pool (diff): {'H6', 'F9', 'F7', 'E4', 'E5', 'F4', 'A1', 'F1', 'H8', 'F8', 'E6', 'F3', 'C3', 'G7', 'I6', 'A6', 'F2', 'C6', 'D6', 'B6', 'I9', 'D4', 'G6', 'F5', 'D5'}
#    2      3689    3489  |1345789  134578   1349  | 13569  1345689   145
#   489      57     3489  | 13489    1348     6    |   2      134     1489
#   4689    3689     1    | 34589   23458    2349  |   35      7     45689
# ------------------------+------------------------+------------------------
#  14579    129      6    |   4      1234     8    |  1359   12359    1259
#    3      128     248   |   14      9      124   |  156    12568     7
#   189     1289    289   |   6      123      57   |   4     12389    1289
# ------------------------+------------------------+------------------------
# ...

# %%
result = sol.solve(diagonal_grid)
sol.display(result)
# Out:
# Pool (diff): {'E2', 'B3', 'G2', 'H2', 'B1', 'G7', 'A2', 'B8', 'H8', 'B5', 'C1', 'C2', 'B9', 'B4', 'A1', 'E5', 'D2', 'I9', 'I2', 'D4', 'C3', 'F2', 'A3', 'B6', 'B7'}
# Pool (diff): {'G7', 'F1', 'F9', 'H8', 'C6', 'H6', 'G6', 'I6', 'D5', 'A6', 'E5', 'A1', 'F5', 'I9', 'D6', 'F7', 'D4', 'F4', 'F8', 'E4', 'C3', 'E6', 'F2', 'F3', 'B6'}
# Pool (diff): {'E2', 'B3', 'D1', 'F1', 'F9', 'E1', 'G3', 'F5', 'H3', 'D2', 'D3', 'F7', 'F4', 'F8', 'C3', 'F2', 'A3', 'E3', 'F6'}
# Pool (diff): {'F1', 'D8', 'C9', 'E8', 'E9', 'H9', 'G9', 'B9', 'F5', 'I9', 'F7', 'D7', 'F4', 'F8', 'D9', 'E7', 'F3', 'A9', 'F6'}
# Pool (diff): {'G8', 'G2', 'G4', 'G7', 'G1', 'F9', 'C9', 'G5', 'H8', 'E9', 'G3', 'H9', 'G6', 'B9', 'I8', 'I9', 'I7', 'H7', 'A9'}
# Pool (diff): {'B3', 'G2', 'H2', 'G1', 'I5', 'G3', 'H1', 'I4', 'I6', 'I8', 'H3', 'D3', 'I9', 'I2', 'I7', 'C3', 'A3', 'E3', 'I1'}
# 2 6 3 |8 1 1 |9 9 4
# 9 5 3 |9 4 6 |2 1 8
# 8 8 1 |3 2 3 |5 7 6
# ------+------+------
# 7 2 6 |4 2 8 |9 5 9
# 3 2 4 |1 9 2 |6 8 7
# ...

# %%
solved = sol.values2grid(solved_diag_sudoku)
result = sol.solve(solved)
sol.display(result)
# Out:
# 2 6 7 |9 4 5 |3 8 1
# 8 5 3 |7 1 6 |2 4 9
# 4 9 1 |8 2 3 |5 7 6
# ------+------+------
# 5 7 6 |4 3 8 |1 9 2
# 3 8 4 |1 9 2 |6 5 7
# 1 2 9 |6 5 7 |4 3 8
# ------+------+------
# 6 4 2 |3 7 9 |8 1 5
# 9 3 5 |2 8 1 |7 6 4
# 7 1 8 |5 6 4 |9 2 3

# %%
before_naked_twins_1 = {'I6': '4', 'H9': '3', 'I2': '6', 'E8': '1', 'H3': '5', 'H7': '8', 'I7': '1', 'I4': '8',
                            'H5': '6', 'F9': '7', 'G7': '6', 'G6': '3', 'G5': '2', 'E1': '8', 'G3': '1', 'G2': '8',
                            'G1': '7', 'I1': '23', 'C8': '5', 'I3': '23', 'E5': '347', 'I5': '5', 'C9': '1', 'G9': '5',
                            'G8': '4', 'A1': '1', 'A3': '4', 'A2': '237', 'A5': '9', 'A4': '2357', 'A7': '27',
                            'A6': '257', 'C3': '8', 'C2': '237', 'C1': '23', 'E6': '579', 'C7': '9', 'C6': '6',
                            'C5': '37', 'C4': '4', 'I9': '9', 'D8': '8', 'I8': '7', 'E4': '6', 'D9': '6', 'H8': '2',
                            'F6': '125', 'A9': '8', 'G4': '9', 'A8': '6', 'E7': '345', 'E3': '379', 'F1': '6',
                            'F2': '4', 'F3': '23', 'F4': '1235', 'F5': '8', 'E2': '37', 'F7': '35', 'F8': '9',
                            'D2': '1', 'H1': '4', 'H6': '17', 'H2': '9', 'H4': '17', 'D3': '2379', 'B4': '27',
                            'B5': '1', 'B6': '8', 'B7': '27', 'E9': '2', 'B1': '9', 'B2': '5', 'B3': '6', 'D6': '279',
                            'D7': '34', 'D4': '237', 'D5': '347', 'B8': '3', 'B9': '4', 'D1': '5'}   
sol.display(before_naked_twins_1)
# Out:
#   1   237   4  | 2357  9   257 |  27   6    8
#   9    5    6  |  27   1    8  |  27   3    4
#   23  237   8  |  4    37   6  |  9    5    1
# ---------------+---------------+---------------
#   5    1   2379| 237  347  279 |  34   8    6
#   8    37  379 |  6   347  579 | 345   1    2
#   6    4    23 | 1235  8   125 |  35   9    7
# ---------------+---------------+---------------
#   7    8    1  |  9    2    3  |  6    4    5
#   4    9    5  |  17   6    17 |  8    2    3
#   23   6    23 |  8    5    4  |  1    7    9

# %%
sol.display(sol.naked_twins(before_naked_twins_1))
# Out:
#   1    27   4  | 235   9    25 |  27   6    8
#   9    5    6  |  27   1    8  |  27   3    4
#   23   27   8  |  4    37   6  |  9    5    1
# ---------------+---------------+---------------
#   5    1   279 |  23  347   29 |  34   8    6
#   8    37   79 |  6    47   59 | 345   1    2
#   6    4    23 | 1235  8   125 |  35   9    7
# ---------------+---------------+---------------
#   7    8    1  |  9    2    3  |  6    4    5
#   4    9    5  |  17   6    17 |  8    2    3
#   23   6    23 |  8    5    4  |  1    7    9
